# %% [markdown]
# # Caesar Cipher

# %%
def decrypt_shift_cipher(ciphertext, key):
  #to do
  decrypt_text = ""
  for char in ciphertext:
      if char.isalpha():
          shifted_ascii = ord(char.lower()) - key
          if shifted_ascii < ord('a'):
              shifted_ascii = ord('z') - (ord('a') - shifted_ascii) + 1
          decrypt_text += chr(shifted_ascii).upper() if char.isupper() else chr(shifted_ascii)
      else:
          decrypt_text += char
  return decrypt_text

# %%
def encrypt_shift_cipher(plaintext, key):
  #to do
  encrypt_text = ""
  for char in plaintext:
      if char.isalpha():
          shifted_ascii = ord(char.lower()) + key
          if shifted_ascii > ord('z'):
              shifted_ascii = ord('a') + (shifted_ascii - ord('z')) - 1
          encrypt_text += chr(shifted_ascii).upper() if char.isupper() else chr(shifted_ascii)
      else:
          encrypt_text += char
  return encrypt_text

# %%
#Decrypt the following text and find out the value of the key using the decrypt_shift_cipher() method.
ciphertext = "KYV HLZTB SIFNE WFO"
for i in range(26):
  print(decrypt_shift_cipher(ciphertext, i) +"Key is:" +str(i) )
# Out:
# KYV HLZTB SIFNE WFOKey is:0
# JXU GKYSA RHEMD VENKey is:1
# IWT FJXRZ QGDLC UDMKey is:2
# HVS EIWQY PFCKB TCLKey is:3
# GUR DHVPX OEBJA SBKKey is:4
# FTQ CGUOW NDAIZ RAJKey is:5
# ESP BFTNV MCZHY QZIKey is:6
# DRO AESMU LBYGX PYHKey is:7
# CQN ZDRLT KAXFW OXGKey is:8
# BPM YCQKS JZWEV NWFKey is:9
# AOL XBPJR IYVDU MVEKey is:10
# ZNK WAOIQ HXUCT LUDKey is:11
# YMJ VZNHP GWTBS KTCKey is:12
# XLI UYMGO FVSAR JSBKey is:13
# WKH TXLFN EURZQ IRAKey is:14
# VJG SWKEM DTQYP HQZKey is:15
# UIF RVJDL CSPXO GPYKey is:16
# THE QUICK BROWN FOXKey is:17
# SGD PTHBJ AQNVM ENWKey is:18
# RFC OSGAI ZPMUL DMVKey is:19
# QEB NRFZH YOLTK CLUKey is:20
# PDA MQEYG XNKSJ BKTKey is:21
# OCZ LPDXF WMJRI AJSKey is:22
# NBY KOCWE VLIQH ZIRKey is:23
# MAX JNBVD UKHPG YHQKey is:24
# LZW IMAUC TJGOF XGPKey is:25

# %%
#Encrypt the following plaintext, using the summation of last 2 digits of your ID as the key
plaintext = "I am Batman"

# %%
key = 12 # Sum of last digit
encrypted_text = encrypt_shift_cipher(plaintext, key)
decrypted_text = decrypt_shift_cipher(encrypted_text, key)

# %%
print(f"Plaintext: {plaintext}")
print(f"Encrypted Text: {encrypted_text} {key}")
print(f"Decrypted Text: {decrypted_text} {key}")
# Out:
# Plaintext: I am Batman
# Encrypted Text: U my Nmfymz 12
# Decrypted Text: I am Batman 12

# %%
for x in range(26):
  encrypted_text = encrypt_shift_cipher(plaintext, x)
  print(f"encrypted_text:{encrypted_text}  Key: {x}")
# Out:
# encrypted_text:I am Batman  Key: 0
# encrypted_text:J bn Cbunbo  Key: 1
# encrypted_text:K co Dcvocp  Key: 2
# encrypted_text:L dp Edwpdq  Key: 3
# encrypted_text:M eq Fexqer  Key: 4
# encrypted_text:N fr Gfyrfs  Key: 5
# encrypted_text:O gs Hgzsgt  Key: 6
# encrypted_text:P ht Ihathu  Key: 7
# encrypted_text:Q iu Jibuiv  Key: 8
# encrypted_text:R jv Kjcvjw  Key: 9
# encrypted_text:S kw Lkdwkx  Key: 10
# encrypted_text:T lx Mlexly  Key: 11
# encrypted_text:U my Nmfymz  Key: 12
# encrypted_text:V nz Ongzna  Key: 13
# encrypted_text:W oa Pohaob  Key: 14
# encrypted_text:X pb Qpibpc  Key: 15
# encrypted_text:Y qc Rqjcqd  Key: 16
# encrypted_text:Z rd Srkdre  Key: 17
# encrypted_text:A se Tslesf  Key: 18
# encrypted_text:B tf Utmftg  Key: 19
# encrypted_text:C ug Vunguh  Key: 20
# encrypted_text:D vh Wvohvi  Key: 21
# encrypted_text:E wi Xwpiwj  Key: 22
# encrypted_text:F xj Yxqjxk  Key: 23
# encrypted_text:G yk Zyrkyl  Key: 24
# encrypted_text:H zl Azslzm  Key: 25

# %% [markdown]
# # Substitution Cipher

# %%
import pandas as pd
def frequency_table(text):
  table = []
  count = 0
  for i in text:
    if i in 'qwertyuiopasdfghjklzxcvbnm':
      count += 1
  for i in range(97,123):
    table.append(text.count(chr(i))/count)
  index = [i[0] for i in sorted(enumerate(table), key=lambda x:x[1])][::-1]
  for i in index:
    print(chr(97+i)+":"+str(table[i]))

# %%
ciphertext = "awbix ildxz kolf a dkzeplld afu zbjjbfm lf bj bz a rwkx iajxpobwwap zdlgbfm a ellgae. jex iajxpobwwap ykxzjblfz awbix afu zex audbjz jl exp ikppxfj buxfjbjt ipbzbz, ildolkfuxu rt exp bfarbwbjt jl pxdxdrxp a olxd. rxnlpx ipahwbfm ahat, jex iajxpobwwap jxwwz awbix jeaj lfx zbux ln jex dkzeplld hbww dagx exp jawwxp afu jex ljexp zbux hbww dagx exp zelpjxp. zex rpxagz lnn jhl obxixz npld jex dkzeplld. lfx zbux dagxz exp zepbfg zdawwxp jeaf xcxp, hebwx afljexp iakzxz exp fxig jl mplh ebme bfjl jex jpxxz, hexpx a obmxlf dbzjagxz exp nlp a zxpoxfj. hbje zldx xnnlpj, awbix rpbfmz expzxwn raig jl exp kzkaw exbmej. zex zjkdrwxz kolf a zdaww xzjajx afu kzxz jex dkzeplld jl pxaie a dlpx aooplopbajx exbmej."
frequency_table(ciphertext)
# Out:
# x:0.140597539543058
# p:0.08260105448154657
# a:0.08084358523725835
# j:0.07908611599297012
# z:0.07381370826010544
# l:0.07381370826010544
# e:0.07205623901581722
# b:0.06854130052724078
# w:0.050966608084358524
# f:0.043936731107205626
# d:0.043936731107205626
# i:0.029876977152899824
# k:0.026362038664323375
# o:0.022847100175746926
# u:0.019332161687170474
# g:0.01757469244288225
# r:0.015817223198594025
# n:0.015817223198594025
# m:0.015817223198594025
# h:0.015817223198594025
# t:0.007029876977152899
# y:0.0017574692442882249
# c:0.0017574692442882249
# v:0.0
# s:0.0
# q:0.0

# %%
ciphertext = "awbix ildxz kolf a dkzeplld afu zbjjbfm lf bj bz a rwkx iajxpobwwap zdlgbfm a ellgae.\n jex iajxpobwwap ykxzjblfz awbix afu zex audbjz jl exp ikppxfj buxfjbjt ipbzbz, ildolkfuxu rt exp bfarbwbjt jl pxdxdrxp a olxd.\n rxnlpx ipahwbfm ahat, jex iajxpobwwap jxwwz awbix jeaj lfx zbux ln jex dkzeplld hbww dagx exp jawwxp afu jex ljexp zbux hbww dagx exp zelpjxp.\n zex rpxagz lnn jhl obxixz npld jex dkzeplld.\n lfx zbux dagxz exp zepbfg zdawwxp jeaf xcxp, hebwx afljexp iakzxz exp fxig jl mplh ebme bfjl jex jpxxz, hexpx a obmxlf dbzjagxz exp nlp a zxpoxfj.\n hbje zldx xnnlpj, awbix rpbfmz expzxwn raig jl exp kzkaw exbmej.\n zex zjkdrwxz kolf a zdaww xzjajx afu kzxz jex dkzeplld jl pxaie a dlpx aooplopbajx exbmej."
ciphertext = ciphertext.replace("x","E")
print(ciphertext)
# Out:
# awbiE ildEz kolf a dkzeplld afu zbjjbfm lf bj bz a rwkE iajEpobwwap zdlgbfm a ellgae.
#  jeE iajEpobwwap ykEzjblfz awbiE afu zeE audbjz jl eEp ikppEfj buEfjbjt ipbzbz, ildolkfuEu rt eEp bfarbwbjt jl pEdEdrEp a olEd.
#  rEnlpE ipahwbfm ahat, jeE iajEpobwwap jEwwz awbiE jeaj lfE zbuE ln jeE dkzeplld hbww dagE eEp jawwEp afu jeE ljeEp zbuE hbww dagE eEp zelpjEp.
#  zeE rpEagz lnn jhl obEiEz npld jeE dkzeplld.
#  lfE zbuE dagEz eEp zepbfg zdawwEp jeaf EcEp, hebwE afljeEp iakzEz eEp fEig jl mplh ebme bfjl jeE jpEEz, heEpE a obmElf dbzjagEz eEp nlp a zEpoEfj.
#  hbje zldE Ennlpj, awbiE rpbfmz eEpzEwn raig jl eEp kzkaw eEbmej.
#  zeE zjkdrwEz kolf a zdaww EzjajE afu kzEz jeE dkzeplld jl pEaie a dlpE aooplopbajE eEbmej.

# %%
ciphertext2 = "xeo iwy djqqod mohzs xeo ezfjrzy, glixjyc l slft, zflyco chzs lgfzii xeo xflyawjh hlydiglqo.\n l coyxho mfooro fwixhod xeo holkoi zv xeo xlhh zln xfooi, gfolxjyc l izzxejyc iutqezyu zv ylxwfo'i tohzdjoi.\n li xsjhjcex doigoydod, xeo ixlfi mocly xz otofco, dzxxjyc xeo jydjcz glykli zv xeo yjcex inu.\n vjfovhjoi dlygod jy xeo toldzs, xeojf mjzhwtjyoigoyx hjcexi vhjgnofjyc hjno xjyu hlyxofyi.\n jy xeo djixlygo, xeo vljyx ewt zv l djixlyx xfljy gzwhd mo eolfd, l fotjydof zv xeo szfhd mouzyd xeji qolgovwh elkoy.\nl hzyo zsh ezzxod jy xeo djixlygo, mfolnjyc xeo ijhoygo zv xeo yjcex.\n xeo igoyx zv vfoiehu mlnod mfold slvxod vfzt l yolfmu gzxxlco, oyxjgjyc lyuzyo vzfxwylxo oyzwce xz glxge l sejvv.\n l fjkof yolfmu chjixoyod jy xeo tzzyhjcex, jxi slxofi fjqqhjyc coyxhu li jx vhzsod zyslfd.\n jx sli l tztoyx zv iofoyjxu lyd ixjhhyoii, l qlwio jy xeo ewixho lyd mwixho zv hjvo, seofo zyo gzwhd ijtqhu opjix lyd ilkzf xeo molwxu zv xeo szfhd lfzwyd xeot.\n"
frequency_table(ciphertext2)
# Out:
# o:0.13474240422721268
# x:0.0977542932628798
# y:0.083223249669749
# l:0.07926023778071334
# j:0.071334214002642
# z:0.06472919418758256
# i:0.05812417437252312
# e:0.05416116248348745
# f:0.05019815059445178
# h:0.0488771466314399
# d:0.04491413474240423
# v:0.03038309114927345
# c:0.03038309114927345
# g:0.026420079260237782
# w:0.021136063408190225
# s:0.019815059445178335
# t:0.018494055482166448
# u:0.017173051519154558
# m:0.017173051519154558
# q:0.011889035667107
# n:0.007926023778071334
# k:0.0066050198150594455
# r:0.002642007926023778
# p:0.001321003963011889
# a:0.001321003963011889
# b:0.0

# %%
ciphertext2 = "xeo iwy djqqod mohzs xeo ezfjrzy, glixjyc l slft, zflyco chzs lgfzii xeo xflyawjh hlydiglqo.\n l coyxho mfooro fwixhod xeo holkoi zv xeo xlhh zln xfooi, gfolxjyc l izzxejyc iutqezyu zv ylxwfo'i tohzdjoi.\n li xsjhjcex doigoydod, xeo ixlfi mocly xz otofco, dzxxjyc xeo jydjcz glykli zv xeo yjcex inu.\n vjfovhjoi dlygod jy xeo toldzs, xeojf mjzhwtjyoigoyx hjcexi vhjgnofjyc hjno xjyu hlyxofyi.\n jy xeo djixlygo, xeo vljyx ewt zv l djixlyx xfljy gzwhd mo eolfd, l fotjydof zv xeo szfhd mouzyd xeji qolgovwh elkoy.\nl hzyo zsh ezzxod jy xeo djixlygo, mfolnjyc xeo ijhoygo zv xeo yjcex.\n xeo igoyx zv vfoiehu mlnod mfold slvxod vfzt l yolfmu gzxxlco, oyxjgjyc lyuzyo vzfxwylxo oyzwce xz glxge l sejvv.\n l fjkof yolfmu chjixoyod jy xeo tzzyhjcex, jxi slxofi fjqqhjyc coyxhu li jx vhzsod zyslfd.\n jx sli l tztoyx zv iofoyjxu lyd ixjhhyoii, l qlwio jy xeo ewixho lyd mwixho zv hjvo, seofo zyo gzwhd ijtqhu opjix lyd ilkzf xeo molwxu zv xeo szfhd lfzwyd xeot.\n"
ciphertext2 = ciphertext2.replace("o","E")
ciphertext2 = ciphertext2.replace("l","A")
ciphertext2 = ciphertext2.replace("e","H")
ciphertext2 = ciphertext2.replace("x","T")
ciphertext2 = ciphertext2.replace("j","I")
ciphertext2 = ciphertext2.replace("i","S")
ciphertext2 = ciphertext2.replace("w","U")
ciphertext2 = ciphertext2.replace("y","N")
ciphertext2 = ciphertext2.replace("d","D")
ciphertext2 = ciphertext2.replace("q","P")
ciphertext2 = ciphertext2.replace("c","G")
ciphertext2 = ciphertext2.replace("g","C")
ciphertext2 = ciphertext2.replace("h","L")
ciphertext2 = ciphertext2.replace("u","Y")
ciphertext2 = ciphertext2.replace("s","W")
ciphertext2 = ciphertext2.replace("z","O")
ciphertext2 = ciphertext2.replace("v","F")
ciphertext2 = ciphertext2.replace("m","B")
ciphertext2 = ciphertext2.replace("f","R")
ciphertext2 = ciphertext2.replace("r","Z")
ciphertext2 = ciphertext2.replace("a","Q")
ciphertext2 = ciphertext2.replace("t","M")
ciphertext2 = ciphertext2.replace("n","K")
ciphertext2 = ciphertext2.replace("p","X")
ciphertext2 = ciphertext2.replace("k","V")

print(ciphertext2)
# Out:
# THE SUN DIPPED BELOW THE HORIZON, CASTING A WARM, ORANGE GLOW ACROSS THE TRANQUIL LANDSCAPE.
#  A GENTLE BREEZE RUSTLED THE LEAVES OF THE TALL OAK TREES, CREATING A SOOTHING SYMPHONY OF NATURE'S MELODIES.
#  AS TWILIGHT DESCENDED, THE STARS BEGAN TO EMERGE, DOTTING THE INDIGO CANVAS OF THE NIGHT SKY.
#  FIREFLIES DANCED IN THE MEADOW, THEIR BIOLUMINESCENT LIGHTS FLICKERING LIKE TINY LANTERNS.
#  IN THE DISTANCE, THE FAINT HUM OF A DISTANT TRAIN COULD BE HEARD, A REMINDER OF THE WORLD BEYOND THIS PEACEFUL HAVEN.
# A LONE OWL HOOTED IN THE DISTANCE, BREAKING THE SILENCE OF THE NIGHT.
#  THE SCENT OF FRESHLY BAKED BREAD WAFTED FROM A NEARBY COTTAGE, ENTICING ANYONE FORTUNATE ENOUGH TO CATCH A WHIFF.
#  A RIVER NEARBY GLISTENED IN THE MOONLIGHT, ITS WATERS RIPPLING GENTLY AS IT FLOWED ONWARD.
#  IT WAS A MOMENT OF SERENITY AND STILLNESS, A PAUSE IN THE HUSTLE AND BUSTLE OF LIFE, WHERE ONE COULD SIMPLY EXIST AND SAVOR THE BEAUTY OF THE WORLD AROUND THEM.
